# %% [markdown]
# # Matplotlib BarChart

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
classes = ["Python", "R", "AI", "ML", "DS"]
class1_students = [30, 10, 20, 25, 10] # out of 100 student in each class
class2_students = [40, 5, 20, 20, 10]
class3_students = [35, 5, 30, 15, 15]

# %%
plt.bar(classes, class1_students)
plt.show()

# %%
plt.barh(classes, class1_students)
plt.show()

# %% [markdown]
# alpha is used to change opacity of bar

# %%
plt.bar(classes, class1_students, width=0.2, align='edge', color='y', edgecolor='black', 
        linewidth=3, alpha=0.9, linestyle='--')
plt.show()

# %%
plt.grid()
plt.bar(classes, class1_students, width=0.4, align='edge', color='y', edgecolor='black', 
        alpha=0.9, linestyle='-')
plt.title("Class", fontsize=15)
plt.xlabel("Subjects")
plt.ylabel("No. of students")
plt.legend("ML Student", loc=1)
plt.show()

# %%
plt.grid()

class_index= np.arange(len(classes))
width=0.2
plt.bar(classes, class1_students, width, align='edge', color='y', edgecolor='black', label='Class1 students')
plt.bar(class_index + width, class2_students, width, align='edge', color='r', edgecolor='black', label='Class2 students')
plt.bar(class_index + width + width, class3_students, width, align='edge', color='g', edgecolor='black', label='Class3 students')
plt.title("Class", fontsize=15)
plt.xlabel("Subjects")
plt.ylabel("No. of students")
plt.legend()
plt.show()
